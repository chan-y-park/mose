# %%
#%matplotlib inline
# %matplotlib nbagg
from IPython.html import widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook

# %%
import mose

# %%
c, d = mose.load('results/parameter_scans/1')
# Out:
# INFO:root:Opening data directory "results/parameter_scans/1"...
# 7427: Opening data directory "results/parameter_scans/1"...
# INFO:root:config file: ./results/parameter_scans/1/config.ini
# 7427: config file: ./results/parameter_scans/1/config.ini

# %%
kp, mp = mose.make_plots(c, d);
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
kp.change_current_plot(2)
kp.figure

# %%
mp.figure

# %%
kp_idx_slider = widgets.IntSlider(min=0, max=len(kp.plots)-1, step=1, value=0)
