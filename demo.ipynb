# %%
#%matplotlib inline
# %matplotlib nbagg
#%matplotlib tk
from IPython.html import widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
import mose
# Out:
# Use IPython notebook backend for matplotlib.

# %%
c, d = mose.load('results/parameter_scans/1')
# Out:
# 11814: Opening data directory "results/parameter_scans/1"...
# 11814: config file: ./results/parameter_scans/1/config.ini

# %%
kp, mp = mose.make_plots(c, d, show_plot=True, 
                         k_wall_network_plot_range=[[-5,5],[-5,5]], 
                         ms_wall_plot_range=[[-2,2],[-2,2]],);
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
import matplotlib
def show_kp(index):
    kp.change_current_plot(index)
    matplotlib.pyplot.show()

# %%
kp_idx_slider = widgets.IntSlider(min=0, max=len(kp.plots)-1, step=1, value=0)
plot_slider = widgets.interactive(show_kp, index=kp_idx_slider)
display(plot_slider)
